# %%
import torch
import math_ext

# %%
device = 'cuda'
a = torch.tensor([1.,2.], dtype=torch.float32, device=device)
b = torch.tensor([3.,4.], dtype=torch.float32, device=device)
c = math_ext.addvec(a,b)
print(c)
# Out:
# tensor([4., 6.], device='cuda:0')
